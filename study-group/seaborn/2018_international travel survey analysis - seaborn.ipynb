# %%
# https://seaborn.pydata.org/tutorial/regression.html

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/jeolmuni/jeolmuni/master/study-group/2018_InternationalTravelBehavior.csv', delimiter = '\t')

# %%
df.head()
# Out:
#    Q1  Q2A1  Q2A2  Q2A3  Q2A4  Q2A5  Q2_1  Q3A1  Q3A2  Q3A3  ...  D_COU  \
# 0   1   NaN   NaN   NaN   NaN   NaN   NaN   1.0   NaN   NaN  ...     13
# 1   1   2.0   NaN   NaN   NaN   NaN   4.0   1.0   NaN   NaN  ...      2
# 2   6   NaN   NaN   NaN   NaN   NaN   NaN   1.0   NaN   NaN  ...      2
# 3   2   NaN   NaN   NaN   NaN   NaN   NaN   1.0   NaN   NaN  ...      2
# 4   3   3.0   NaN   NaN   NaN   NaN   2.0   1.0   NaN   NaN  ...      2
#
#    D_GEN  D_AGE  D_Q5_1  D_Q13  D_Q1  DD_Q1        WT  COUNTRY  CITY
# 0      1      3       1      1     1      1  0.258338       12  1513
# 1      1      5       1      1     1      1  1.497972        2   204
# 2      2      2       1      1     4      2  1.806581        2   211
# 3      2      2       1      1     2      2  1.609837        2   253
# 4      2      3       1      1     3      2  1.872946        2   201
#
# [5 rows x 410 columns]

# %%
df.info('COUNTRY')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16469 entries, 0 to 16468
# Data columns (total 410 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   Q1              int64
#  1   Q2A1            float64
#  2   Q2A2            float64
#  3   Q2A3            float64
#  4   Q2A4            float64
#  5   Q2A5            float64
#  6   Q2_1            float64
#  7   Q3A1            float64
#  8   Q3A2            float64
#  9   Q3A3            float64
#  10  Q3A4            float64
#  11  Q3B1            float64
#  12  Q3B2            float64
#  13  Q4              int64
#  14  Q4_1A1          float64
#  15  Q4_1A2          float64
#  16  Q4_1A3          float64
#  17  Q4_1A4          float64
#  18  Q4_1A5          float64
#  19  Q4_1A6          float64
#  20  Q4_1A7          float64
#  21  Q4_1A8          float64
#  22  Q4_1A9          float64
#  23  Q4_1A10         float64
#  24  Q5_1            int64
#  25  Q5_2A1          float64
#  26  Q5_2A2          float64
#  27  Q5_2A3          float64
#  28  Q6_1A1          int64
#  29  Q6_1A2          float64
#  30  Q6_1A3          float64
#  31  Q6_2A1          float64
#  32  Q6_2A2          float64
#  33  Q6_2A3          float64
#  34  Q6_3A1          int64
#  35  Q6_3A2          float64
#  36  Q6_3A3          float64
#  37  Q7              int64
#  38  Q8A1            int64
#  39  Q8A2            float64
#  40  Q8A3            float64
#  41  Q9_1A1          int64
#  42  Q9_1A2          float64
#  43  Q9_1A3          float64
#  44  Q9_1A4          float64
#  45  Q9_1A5          float64
#  46  Q9_1A6          float64
#  47  Q9_1A7          float64
#  48  Q9_1A8          float64
#  49  Q9_1A9          float64
#  50  Q9_1A10         float64
#  51  Q9_1A11         float64
#  52  Q9_1A12         float64
#  53  Q9_1A13         float64
#  54  Q9_1A14         float64
#  55  Q9_1A15         float64
#  56  Q9_1A16         float64
#  57  Q9_1A17         float64
#  58  Q9_1A18         float64
#  59  Q9_1A19         float64
#  60  Q9_1A20         float64
#  61  Q9_2A1          int64
#  62  Q9_2A2          float64
#  63  Q9_2A3          float64
#  64  Q10_1A1         float64
#  65  Q10_1A2         float64
#  66  Q10_1A3         float64
#  67  Q10_1A4         float64
#  68  Q10_1A5         float64
#  69  Q10_1A6         float64
#  70  Q10_1A7         float64
#  71  Q10_1A8         float64
#  72  Q10_1A9         float64
#  73  Q10_1A10        float64
#  74  Q10_1A11        float64
#  75  Q10_1A12        float64
#  76  Q10_1A13        float64
#  77  Q10_1A14        float64
#  78  Q10_1A15        float64
#  79  Q10_1A16        float64
#  80  Q10_1A17        float64
#  81  Q10_1B1         float64
#  82  Q10_1B2         float64
#  83  Q10_1B3         float64
#  84  Q10_1B4         float64
#  85  Q10_1B5         float64
#  86  Q10_1B6         float64
#  87  Q10_1B7         float64
#  88  Q10_1B8         float64
#  89  Q10_2_1A1       float64
#  90  Q10_2_2A1       float64
#  91  Q10_2_3A1       float64
#  92  Q10_2_4A1       float64
#  93  Q10_2_5A1       float64
#  94  Q10_2_6A1       float64
#  95  Q10_2_7A1       float64
#  96  Q10_2_8A1       float64
#  97  Q10_2_9A1       float64
#  98  Q10_2_10A1      float64
#  99  Q10_2_11A1      float64
#  100 Q10_2_12A1      float64
#  101 Q10_2_13A1      float64
#  102 Q10_2_14A1      float64
#  103 Q10_2_15A1      float64
#  104 Q10_2_16A1      float64
#  105 Q10_2_17A1      float64
#  106 MQ10_2_1A1      float64
#  107 MQ10_2_2A1      float64
#  108 MQ10_2_3A1      float64
#  109 MQ10_2_4A1      float64
#  110 MQ10_2_5A1      float64
#  111 MQ10_2_6A1      float64
#  112 MQ10_2_7A1      float64
#  113 MQ10_2_8A1      float64
#  114 MQ10_2_9A1      float64
#  115 MQ10_2_10A1     float64
#  116 MQ10_2_11A1     float64
#  117 MQ10_2_12A1     float64
#  118 MQ10_2_13A1     float64
#  119 MQ10_2_14A1     float64
#  120 MQ10_2_15A1     float64
#  121 MQ10_2_16A1     float64
#  122 MQ10_2_17A1     float64
#  123 Q10_2_1A2       float64
#  124 Q10_2_2A2       float64
#  125 Q10_2_3A2       float64
#  126 Q10_2_4A2       float64
#  127 Q10_2_5A2       float64
#  128 Q10_2_6A2       float64
#  129 Q10_2_7A2       float64
#  130 Q10_2_8A2       float64
#  131 Q10_2_9A2       float64
#  132 Q10_2_10A2      float64
#  133 Q10_2_11A2      float64
#  134 Q10_2_12A2      float64
#  135 Q10_2_13A2      float64
#  136 Q10_2_14A2      float64
#  137 Q10_2_15A2      float64
#  138 Q10_2_16A2      float64
#  139 Q10_2_17A2      float64
#  140 MQ10_2_1A2      float64
#  141 MQ10_2_2A2      float64
#  142 MQ10_2_3A2      float64
#  143 MQ10_2_4A2      float64
#  144 MQ10_2_5A2      float64
#  145 MQ10_2_6A2      float64
#  146 MQ10_2_7A2      float64
#  147 MQ10_2_8A2      float64
#  148 MQ10_2_9A2      float64
#  149 MQ10_2_10A2     float64
#  150 MQ10_2_11A2     float64
#  151 MQ10_2_12A2     float64
#  152 MQ10_2_13A2     float64
#  153 MQ10_2_14A2     float64
#  154 MQ10_2_15A2     float64
#  155 MQ10_2_16A2     float64
#  156 MQ10_2_17A2     float64
#  157 Q10_3A1         int64
#  158 MQ10_3A1        float64
#  159 CQ10_3A1        int64
#  160 Q10_3A2         int64
#  161 MQ10_3A2        float64
#  162 CQ10_3A2        int64
#  163 Q10_4A1         int64
#  164 Q10_4A2         float64
#  165 Q10_4A3         float64
#  166 Q10_4A4         float64
#  167 Q10_4A5         float64
#  168 Q10_4A6         float64
#  169 Q10_4A7         float64
#  170 Q10_4A8         float64
#  171 Q10_4A9         float64
#  172 Q10_4A10        float64
#  173 Q10_4A11        float64
#  174 Q10_4A12        float64
#  175 Q10_4A13        float64
#  176 Q10_4A14        float64
#  177 Q10_4A15        float64
#  178 Q10_4A16        float64
#  179 Q10_4A17        float64
#  180 Q10_4A18        float64
#  181 Q10_4A19        float64
#  182 Q10_4A20        float64
#  183 Q10_4A21        float64
#  184 Q10_4A22        float64
#  185 Q10_4A23        float64
#  186 Q10_4A24        float64
#  187 Q10_4A25        float64
#  188 Q10_4A26        float64
#  189 Q10_4A27        float64
#  190 Q10_4A28        float64
#  191 Q10_4A29        float64
#  192 Q10_4A30        float64
#  193 Q10_5A1         int64
#  194 Q10_5A2         float64
#  195 Q10_5A3         float64
#  196 Q10_5A4         float64
#  197 Q10_5A5         float64
#  198 Q10_5A6         float64
#  199 Q10_5A7         float64
#  200 Q10_5A8         float64
#  201 Q10_5A9         float64
#  202 Q10_5_1         float64
#  203 Q10_5_2         float64
#  204 Q10_5_3         float64
#  205 Q10_5_4         float64
#  206 Q10_5_5         float64
#  207 Q10_5_6         float64
#  208 Q10_5_7         float64
#  209 Q10_5_8         float64
#  210 Q11A1           int64
#  211 Q11A2           float64
#  212 Q11A3           float64
#  213 Q12_1A1         int64
#  214 Q12_1A2         float64
#  215 Q12_1A3         float64
#  216 Q12_2A1         float64
#  217 Q12_2A2         float64
#  218 Q12_2A3         float64
#  219 Q13             int64
#  220 Q14_1T          float64
#  221 Q14_1A          float64
#  222 Q14_1B          float64
#  223 Q14_1C          float64
#  224 Q14_2_1         float64
#  225 Q14_2_2         float64
#  226 Q14_2_3         float64
#  227 Q14_2_4         float64
#  228 Q14_2_5         float64
#  229 Q14_2_6         float64
#  230 Q14_2_7         float64
#  231 Q14_2_8         float64
#  232 Q14_2_9         float64
#  233 MQ14_1T         float64
#  234 MQ14_1A         float64
#  235 MQ14_1B         float64
#  236 MQ14_1C         float64
#  237 MQ14_2_1        float64
#  238 MQ14_2_2        float64
#  239 MQ14_2_3        float64
#  240 MQ14_2_4        float64
#  241 MQ14_2_5        float64
#  242 MQ14_2_6        float64
#  243 MQ14_2_7        float64
#  244 MQ14_2_8        float64
#  245 MQ14_2_9        float64
#  246 CQ14_1T         int64
#  247 CQ14_1A         int64
#  248 CQ14_1B         int64
#  249 CQ14_1C         int64
#  250 CQ14_2_1        float64
#  251 CQ14_2_2        float64
#  252 CQ14_2_3        int64
#  253 CQ14_2_4        int64
#  254 CQ14_2_5        int64
#  255 CQ14_2_6        int64
#  256 CQ14_2_7        int64
#  257 CQ14_2_8        int64
#  258 CQ14_2_9        int64
#  259 I_Q14_1T        float64
#  260 I_Q14_2_1       float64
#  261 I_Q14_2_3       float64
#  262 I_Q14_2_4       float64
#  263 I_Q14_2_5       float64
#  264 I_Q14_2_6       float64
#  265 I_Q14_2_7       float64
#  266 I_Q14_2_8       float64
#  267 I_Q14_2_9       float64
#  268 I_MQ14_1T       float64
#  269 I_MQ14_2_1      float64
#  270 I_MQ14_2_3      float64
#  271 I_MQ14_2_4      float64
#  272 I_MQ14_2_5      float64
#  273 I_MQ14_2_6      float64
#  274 I_MQ14_2_7      float64
#  275 I_MQ14_2_8      float64
#  276 I_MQ14_2_9      float64
#  277 I_CQ14_1T       float64
#  278 I_CQ14_2_1      float64
#  279 I_CQ14_2_3      float64
#  280 I_CQ14_2_4      float64
#  281 I_CQ14_2_5      float64
#  282 I_CQ14_2_6      float64
#  283 I_CQ14_2_7      float64
#  284 I_CQ14_2_8      float64
#  285 I_CQ14_2_9      float64
#  286 G_Q14_1T        float64
#  287 G_Q14_2_2       float64
#  288 G_Q14_2_3       float64
#  289 G_Q14_2_4       float64
#  290 G_Q14_2_5       float64
#  291 G_Q14_2_6       float64
#  292 G_Q14_2_7       float64
#  293 G_Q14_2_8       float64
#  294 G_Q14_2_9       float64
#  295 G_MQ14_1T       float64
#  296 G_MQ14_2_2      float64
#  297 G_MQ14_2_3      float64
#  298 G_MQ14_2_4      float64
#  299 G_MQ14_2_5      float64
#  300 G_MQ14_2_6      float64
#  301 G_MQ14_2_7      float64
#  302 G_MQ14_2_8      float64
#  303 G_MQ14_2_9      float64
#  304 G_CQ14_1T       float64
#  305 G_CQ14_2_2      float64
#  306 G_CQ14_2_3      float64
#  307 G_CQ14_2_4      float64
#  308 G_CQ14_2_5      float64
#  309 G_CQ14_2_6      float64
#  310 G_CQ14_2_7      float64
#  311 G_CQ14_2_8      float64
#  312 G_CQ14_2_9      float64
#  313 A_Q14_1T        float64
#  314 A_Q14_2_2       float64
#  315 A_Q14_2_3       float64
#  316 A_Q14_2_4       float64
#  317 A_Q14_2_5       float64
#  318 A_Q14_2_6       float64
#  319 A_Q14_2_7       float64
#  320 A_Q14_2_8       float64
#  321 A_Q14_2_9       float64
#  322 A_MQ14_1T       float64
#  323 A_MQ14_2_2      float64
#  324 A_MQ14_2_3      float64
#  325 A_MQ14_2_4      float64
#  326 A_MQ14_2_5      float64
#  327 A_MQ14_2_6      float64
#  328 A_MQ14_2_7      float64
#  329 A_MQ14_2_8      float64
#  330 A_MQ14_2_9      float64
#  331 A_CQ14_1T       float64
#  332 A_CQ14_2_2      float64
#  333 A_CQ14_2_3      float64
#  334 A_CQ14_2_4      float64
#  335 A_CQ14_2_5      float64
#  336 A_CQ14_2_6      float64
#  337 A_CQ14_2_7      float64
#  338 A_CQ14_2_8      float64
#  339 A_CQ14_2_9      float64
#  340 GA_Q14_2_1T     float64
#  341 GA_Q14_2_2      float64
#  342 GA_Q14_2_3      float64
#  343 GA_Q14_2_4      float64
#  344 GA_Q14_2_5      float64
#  345 GA_Q14_2_6      float64
#  346 GA_Q14_2_7      float64
#  347 GA_Q14_2_8      float64
#  348 GA_Q14_2_9      float64
#  349 GA_MQ14_1T      float64
#  350 GA_MQ14_2_2     float64
#  351 GA_MQ14_2_3     float64
#  352 GA_MQ14_2_4     float64
#  353 GA_MQ14_2_5     float64
#  354 GA_MQ14_2_6     float64
#  355 GA_MQ14_2_7     float64
#  356 GA_MQ14_2_8     float64
#  357 GA_MQ14_2_9     float64
#  358 GA_CQ14_1T      float64
#  359 GA_CQ14_2_2     float64
#  360 GA_CQ14_2_3     float64
#  361 GA_CQ14_2_4     float64
#  362 GA_CQ14_2_5     float64
#  363 GA_CQ14_2_6     float64
#  364 GA_CQ14_2_7     float64
#  365 GA_CQ14_2_8     float64
#  366 GA_CQ14_2_9     float64
#  367 DAY_MQ14_1T     float64
#  368 DAY_I_MQ14_1T   float64
#  369 DAY_A_MQ14_1T   float64
#  370 DAY_GA_MQ14_1T  float64
#  371 DAY_CQ14_1T     float64
#  372 DAY_I_CQ14_1T   float64
#  373 DAY_A_CQ14_1T   float64
#  374 DAY_GA_CQ14_1T  float64
#  375 Q15_1           int64
#  376 Q15_2A1         int64
#  377 Q15_2A2         int64
#  378 Q15_2A3         int64
#  379 Q15_2A4         int64
#  380 Q15_2A5         int64
#  381 Q15_2A6         int64
#  382 Q15_2A7         int64
#  383 Q15_2A8         int64
#  384 Q15_2A9         int64
#  385 Q15_2A10        int64
#  386 Q15_2A11        int64
#  387 Q15_2A12        int64
#  388 Q16             int64
#  389 Q17             int64
#  390 Q18A1           int64
#  391 Q18A2           int64
#  392 Q19             float64
#  393 Q20_1           float64
#  394 Q20_2A1         float64
#  395 Q20_2A2         float64
#  396 Q20_2A3         float64
#  397 ID              int64
#  398 D_MON           int64
#  399 D_QUA           int64
#  400 D_COU           int64
#  401 D_GEN           int64
#  402 D_AGE           int64
#  403 D_Q5_1          int64
#  404 D_Q13           int64
#  405 D_Q1            int64
#  406 DD_Q1           int64
#  407 WT              float64
#  408 COUNTRY         int64
#  409 CITY            int64
# dtypes: float64(352), int64(58)
# memory usage: 51.5 MB

# %%
sns.set(color_codes = True)

# %% [markdown]
# ## Functions to draw linear regression models¶
#
# #### Two main functions in seaborn are used to visualize a linear relationship as determined through regression: regplot() and lmplot()

# %%
# the relationship between length of stay (MQ10_3A2) and expenditure (MQ14_1T)

df['log_LOS'] = ''
#df['log_LOS'] = NaN
df['log_Exp'] = ''

# %%
df['log_LOS'] = np.log(df['MQ10_3A2'])
df['log_Exp'] = np.log(df['MQ14_1T'])

# %%
sns.regplot(x='MQ10_3A2', y='MQ14_1T', data=df)
#sns.regplot(x='MQ10_3A2', y='Q15_1', data=df)

# %%
sns.regplot(x='log_LOS', y='log_Exp', data=df)

# %%
sns.lmplot(x='MQ10_3A2', y='MQ14_1T', data=df)

# %%
# adding 'jitter':  some random noise (“jitter”) to the discrete values to make the distribution of those values more clear
sns.lmplot(x='MQ10_3A2', y='MQ14_1T', data=df, x_jitter=.05)

# %%
# To collapse over the observations in each discrete bin to plot an estimate of central tendency along with a confidence interval
sns.lmplot(x='MQ10_3A2', y='MQ14_1T', data=df, x_estimator = np.mean)

# %% [markdown]
# # Fitting different kinds of models¶

# %%
anscombe = sns.load_dataset("anscombe")
anscombe.head(50)
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# 37      IV   8.0   8.47
# 38      IV   8.0   7.04
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89

# %%
sns.lmplot(x = 'x', y = 'y', data = anscombe)

# %%
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'I'"), scatter_kws={"s": 80});

# %%
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'II'"), 
           ci=None, scatter_kws={"s": 80}); #ci refers to confidence interval

# %%
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'III'"), 
           ci=None, scatter_kws={"s": 80});

# %%
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'IV'"), 
           ci=None, scatter_kws={"s": 80});

# %%
# a polynomial regression model to explore simple kinds of nonlinear trends
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'II'"), order=2,
           ci=None, scatter_kws={"s": 80});

# %%
#to fit a robust regression, which uses a different loss function to downweight relatively large residuals:

sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'III'"), robust=True,
           ci=None, scatter_kws={"s": 80});

# %%
# binary variable (D_GEN: 성별) 0 - 여자, 1 - 남자 
df['D_GEN'].replace(2,0, inplace=True)
df['D_GEN']

sns.lmplot(x='MQ10_3A2', y='D_GEN', data=df, y_jitter=0.03)

# %%
sns.lmplot(x='MQ10_3A2', y='D_GEN', 
           logistic = True, data=df, y_jitter=0.03)

# %%
# to fit a nonparametric regression using a lowess smoother
sns.lmplot(x='MQ10_3A2', y='MQ14_1T', data=df, lowess=True)

# %%
# residplot(): for checking whether the simple regression model is appropriate for a dataset.

sns.residplot(x='x', y='y', data=anscombe.query("dataset=='I'"), scatter_kws={"s":80});

# %%
#If there is structure in the residuals, it suggests that simple linear regression is not appropriate:

sns.residplot(x='x', y='y', data=anscombe.query("dataset=='II'"), scatter_kws={"s":80});

# %% [markdown]
# # Conditioning on other variables¶
# ### To address  “how does the relationship between these two variables change as a function of a third variable?”
# #### While regplot() always shows a single relationship, lmplot() combines regplot() with FacetGrid to provide an easy interface to show a linear regression on “faceted” plots that allow you to explore interactions with up to three additional categorical variables

# %%
# To consider a categorical variable
sns.lmplot(x='MQ10_3A2', y='MQ14_1T', hue='D_GEN', data=df); #hue: Grouping variable

# %%
# to use different scatterplot markers to make plots the reproduce to black and white better. You also have full control over the colors used:

sns.lmplot(x='MQ10_3A2', y='MQ14_1T', hue='D_GEN', data=df, markers=['x', 'o'], palette='Set1');

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# To add another variable, 
#you can draw multiple “facets” which each level of the variable appearing in the rows or columns of the grid:

sns.lmplot(x="total_bill", y="tip", hue="smoker", col="time", data=tips);

# %%
df['D_GEN'].replace('여자',"female", inplace=True)
df['D_GEN'].replace('남자',"male", inplace=True)

df['D_GEN']
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 16464    0
# 16465    1
# 16466    0
# 16467    1
# 16468    0
# Name: D_GEN, Length: 16469, dtype: int64

# %%
sns.lmplot(x='MQ10_3A2', y='MQ14_1T', hue='D_GEN', data=df, markers=['x', 'o'], palette='Set1');

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker",
           col="time", row="sex", data=tips);

# %%
tips['big_tip'] = (tips['tip']/tips['total_bill']) > .15
sns.lmplot(x='total_bill', y='big_tip',data=tips, y_jitter=.03)

# %%
sns.lmplot(x='total_bill', y='big_tip',data=tips,logistic=True, y_jitter=.03)

# %% [markdown]
# # Controlling the size and shape of the plot¶

# %%
f, ax = plt.subplots(figsize=(5, 6))
sns.regplot(x="total_bill", y="tip", data=tips, ax=ax);

# %%
f, ax = plt.subplots(figsize=(5, 6))
sns.regplot(x="MQ10_3A2", y="MQ14_1T", data=df, ax=ax); #ax indicates axis

# %%
sns.lmplot(x="total_bill", y="tip", data=tips, col="day", col_wrap=2, height=3)

# %%
sns.lmplot(x="total_bill", y="tip", data=tips, col="day", aspect=.5)

# %% [markdown]
# # Plotting a regression in other contexts¶
#
# ### jointplot() - distributions of the data
# ### jointplot() can use regplot() to show the linear regression fit on the joint axes by passing kind="reg":
#
# ### pairplot() - with kind="reg" combines regplot() and PairGrid to show the linear relationship
# #### PairGrid() is used to show multiple relationships between different pairings of the variables in a dataset

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind='reg');

# %%
sns.jointplot(x="MQ10_3A2", y="MQ14_1T", data=df, kind='reg');

# %%
sns.pairplot(tips, x_vars=['total_bill','size'], y_vars=["tip"], height=5, aspect=.8, kind='reg');
