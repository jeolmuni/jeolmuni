# %%
# Reference:
- https://github.com/chezou/tabula-py/blob/master/examples/tabula_example.ipynb
- https://blog.chezo.uno/tabula-py-extract-table-from-pdf-into-python-dataframe-6c7acfa5f302

# %%
import tabula
#the pd is the standard shorthand for pandas
import pandas as pd

# %%
# read pdf as list
from tabula import read_pdf
df = read_pdf("data/Telecommination_Sept_2019.pdf")
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.
# Got stderr: Apr 25, 2020 2:17:18 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider loadDiskCache
# WARNING: New fonts found, font cache will be re-built
# Apr 25, 2020 2:17:18 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Building on-disk font cache, this may take a while
# Apr 25, 2020 2:17:18 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Finished building on-disk font cache, found 406 fonts
# Apr 25, 2020 2:17:18 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFO: OpenType Layout tables used in font TimesNewRomanPS-BoldMT are not implemented in PDFBox and will be ignored
# Apr 25, 2020 2:17:18 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFO: OpenType Layout tables used in font TimesNewRomanPS-BoldMT are not implemented in PDFBox and will be ignored
# ...

# %%
df
# Out:
# [   Unnamed: 0   Unnamed: 1 Distribution of  Cellular Mobile Subscribers  \
#  0      Months          NaN                                          NaN
#  1         NaN        Total                   Moblink Zong Ufone Telenor
#  2     January  133,606,004  37,617,798 24,366,879 25,033,285 33,748,975
#  3    February  134,609,592  37,775,100 24,901,387 24,557,841 34,491,019
#  4       March  136,469,886  38,154,534 25,594,413 24,570,563 35,210,948
#  5       April  137,683,211  38,300,475 25,981,940 24,572,998 35,876,539
#  6         May  139,198,479  38,444,357 26,736,308 24,645,598 36,311,451
#  7        June  139,974,754  38,768,346 27,197,048 24,352,717 36,571,820
#  8        July  140,022,516  38,914,005 27,411,737 24,176,583 36,523,951
#  9      August  138,589,661  38,779,034 27,186,703 23,495,150 36,344,492
#  10  September  137,605,819  38,700,176 26,952,302 23,001,127 36,325,193
#  11    October  137,152,666  38,516,056 26,985,261 22,554,332 36,644,862
# ...

# %%
# read pdf as JSON
json = read_pdf("data/Telecommination_Sept_2019.pdf", pages="all")
json
# Out:
# Got stderr: Apr 25, 2020 2:20:07 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFO: OpenType Layout tables used in font TimesNewRomanPS-BoldMT are not implemented in PDFBox and will be ignored
# Apr 25, 2020 2:20:08 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFO: OpenType Layout tables used in font TimesNewRomanPS-BoldMT are not implemented in PDFBox and will be ignored
# Apr 25, 2020 2:20:08 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFO: OpenType Layout tables used in font TimesNewRomanPS-BoldMT are not implemented in PDFBox and will be ignored
# Apr 25, 2020 2:20:08 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFO: OpenType Layout tables used in font TimesNewRomanPS-BoldMT are not implemented in PDFBox and will be ignored
# Apr 25, 2020 2:20:08 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFO: OpenType Layout tables used in font TimesNewRomanPS-BoldMT are not implemented in PDFBox and will be ignored
# ...

# %%
# another example

# %%
pdf_path = "https://github.com/chezou/tabula-py/raw/master/tests/resources/data.pdf"
dfs = tabula.read_pdf(pdf_path, stream=True, pages ="all")
len(dfs)
# Out:
# Got stderr: Picked up JAVA_TOOL_OPTIONS: -Dfile.encoding=UTF-8
# 4

# %%
df1 = tabula.read_pdf(pdf_path, pages=3, stream=True)[0]
df1.head()
# Out:
# Got stderr: Picked up JAVA_TOOL_OPTIONS: -Dfile.encoding=UTF-8
#     len supp  dose
# 0   4.2   VC   0.5
# 1  11.5   VC   0.5
# 2   7.3   VC   0.5
# 3   5.8   VC   0.5
# 4   6.4   VC   0.5

# %%
df2 = tabula.read_pdf(pdf_path, pages="1-2,3", stream=True)[0]
df2
# Out:
# Got stderr: Picked up JAVA_TOOL_OPTIONS: -Dfile.encoding=UTF-8
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...
